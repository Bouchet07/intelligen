# %%
from intelligen.linregress import *
from intelligen.AI import *
from intelligen.interpolate import *
from intelligen.numeric import *
import numpy as np

# %%
X = np.random.rand(10000) * 4 -2
Y = X + np.random.random(X.shape)*4

# %%
MLR = LinearRegression()
MLR.fit(X, Y)
y_pred = MLR.predict()
MLR.plot()
print(f'Error linr: {MLR.mse()}')
# Out:
# Error linr: 1.336907298930538

# %%
GD = GradientDescent()
GD.fit(X, Y, epoch=50)
y_pred2 = GD.predict()
GD.plot(log = True)
#GD.plot_mse()
print(f'Error GD  : {GD.mse[-1]}')
# Out:
# Error GD  : 1.3369921394928843

# %%
SGD = GradientDescent()
SGD.fit(X, Y, epoch=50, stochastic=True)
y_pred2 = SGD.predict()
SGD.plot(log = True)
#GD.plot_mse()
print(f'Error SGD : {SGD.show_mse()}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2720/295740631.py in <module>
#       4 SGD.plot(log = True)
#       5 #GD.plot_mse()
# ----> 6 print(f'Error SGD : {SGD.show_mse()}')
#
# AttributeError: 'GradientDescent' object has no attribute 'show_mse'

# %%
x = np.array([2,3,4])
x**2
# Out:
# array([ 4,  9, 16], dtype=int32)
